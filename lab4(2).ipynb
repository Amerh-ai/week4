# %%
num = int(input("Enter a number:"))
for i in range(1,13):
    product= num*i
    if product %3==0:
       continue
    if product>50:
       break
    print(f"{num} x{i} ={product}")
# Out:
# Enter a number: 4
# 4 x1 =4
# 4 x2 =8
# 4 x4 =16
# 4 x5 =20
# 4 x7 =28
# 4 x8 =32
# 4 x10 =40
# 4 x11 =44
