# %%
total =0
for i in range(10):
    num = int(input("Enter anumber:"))
    if num ==0:
        break
    if num<0:
         continue
    if num % 2 ==0:
         total+=num
print("Final sum =",total)
# Out:
# Enter anumber: 5
# Enter anumber: -4
# Enter anumber: 6
# Enter anumber: 1
# Enter anumber: 0
# Final sum = 6
