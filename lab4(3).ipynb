# %%
secret = 10
attempts = 0
while True:
    guess = int(input("Guess the number (1-20): "))

    if guess < 1 or guess > 20:
        continue

    attempts += 1

    if guess == secret:
        print("Correct!")
        break
    else:
        print("Try again!")

print("Valid attempts =", attempts)
